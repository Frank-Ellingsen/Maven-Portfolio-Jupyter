# %%
import  numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("powerconsumption.csv",usecols=['Datetime','PowerConsumption_Zone1','PowerConsumption_Zone2','PowerConsumption_Zone3'],parse_dates=['Datetime'])
df['Total PowerConsumption']=df['PowerConsumption_Zone1']+df['PowerConsumption_Zone2']+df['PowerConsumption_Zone3']
df['Hour']=df['Datetime'].dt.hour
df['DayofWeek']=df['Datetime'].dt.dayofweek
df
# Out:
#                  Datetime  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0     2017-01-01 00:00:00             34055.69620             16128.87538
# 1     2017-01-01 00:10:00             29814.68354             19375.07599
# 2     2017-01-01 00:20:00             29128.10127             19006.68693
# 3     2017-01-01 00:30:00             28228.86076             18361.09422
# 4     2017-01-01 00:40:00             27335.69620             17872.34043
# ...                   ...                     ...                     ...
# 52411 2017-12-30 23:10:00             31160.45627             26857.31820
# 52412 2017-12-30 23:20:00             30430.41825             26124.57809
# 52413 2017-12-30 23:30:00             29590.87452             25277.69254
# 52414 2017-12-30 23:40:00             28958.17490             24692.23688
# 52415 2017-12-30 23:50:00             28349.80989             24055.23167
#
#        PowerConsumption_Zone3  Total PowerConsumption  Hour  DayofWeek
# ...

# %%
df.set_index('Datetime',inplace=True)
df
# Out:
#                      PowerConsumption_Zone1  PowerConsumption_Zone2  \
# Datetime
# 2017-01-01 00:00:00             34055.69620             16128.87538
# 2017-01-01 00:10:00             29814.68354             19375.07599
# 2017-01-01 00:20:00             29128.10127             19006.68693
# 2017-01-01 00:30:00             28228.86076             18361.09422
# 2017-01-01 00:40:00             27335.69620             17872.34043
# ...                                     ...                     ...
# 2017-12-30 23:10:00             31160.45627             26857.31820
# 2017-12-30 23:20:00             30430.41825             26124.57809
# 2017-12-30 23:30:00             29590.87452             25277.69254
# 2017-12-30 23:40:00             28958.17490             24692.23688
# 2017-12-30 23:50:00             28349.80989             24055.23167
#
#                      PowerConsumption_Zone3  Total PowerConsumption  Hour  \
# Datetime
# ...

# %%
dfr=df.resample("H").mean()
dfr
# Out:
#                      PowerConsumption_Zone1  PowerConsumption_Zone2  \
# Datetime
# 2017-01-01 00:00:00            29197.974683            18026.747720
# 2017-01-01 01:00:00            24657.215190            16078.419453
# 2017-01-01 02:00:00            22083.037973            14330.699088
# 2017-01-01 03:00:00            20811.139240            13219.452887
# 2017-01-01 04:00:00            20475.949367            12921.580547
# ...                                     ...                     ...
# 2017-12-30 19:00:00            37513.814957            32497.698680
# 2017-12-30 20:00:00            37008.871988            32020.251610
# 2017-12-30 21:00:00            35358.174905            30757.901197
# 2017-12-30 22:00:00            33993.409380            28477.447070
# 2017-12-30 23:00:00            30107.984788            25713.409022
#
#                      PowerConsumption_Zone3  Total PowerConsumption  Hour  \
# Datetime
# ...

# %%
dfrj=dfr.loc["2017-01"]
dfr
# Out:
#                      PowerConsumption_Zone1  PowerConsumption_Zone2  \
# Datetime
# 2017-01-01 00:00:00            29197.974683            18026.747720
# 2017-01-01 01:00:00            24657.215190            16078.419453
# 2017-01-01 02:00:00            22083.037973            14330.699088
# 2017-01-01 03:00:00            20811.139240            13219.452887
# 2017-01-01 04:00:00            20475.949367            12921.580547
# ...                                     ...                     ...
# 2017-12-30 19:00:00            37513.814957            32497.698680
# 2017-12-30 20:00:00            37008.871988            32020.251610
# 2017-12-30 21:00:00            35358.174905            30757.901197
# 2017-12-30 22:00:00            33993.409380            28477.447070
# 2017-12-30 23:00:00            30107.984788            25713.409022
#
#                      PowerConsumption_Zone3  Total PowerConsumption  Hour  \
# Datetime
# ...

# %%
dfrj[['PowerConsumption_Zone1','PowerConsumption_Zone2','PowerConsumption_Zone3']].plot.area(
    title="Hourly Comsumption Jan 2017",xlabel="Date",ylabel="KwH")
sns.despine()
plt.show()

# %%
df.columns
# Out:
# Index(['PowerConsumption_Zone1', 'PowerConsumption_Zone2',
#        'PowerConsumption_Zone3', 'Total PowerConsumption', 'Hour',
#        'DayofWeek'],
#       dtype='object')

# %%
table=pd.pivot_table(df,index='Hour',columns='DayofWeek',values='Total PowerConsumption',
                     aggfunc={'Total PowerConsumption':np.mean})

sns.heatmap(table,cmap='coolwarm').set(title='Power Consumption by Hour & Day of Week');

# %%
table
# Out:
# DayofWeek             0             1             2             3  \
# Hour
# 0          67817.926234  67935.356547  68239.842528  68293.632675
# 1          61755.422717  61868.544847  62022.724317  62187.544469
# 2          58647.360270  58801.200586  58798.761412  59063.328906
# 3          56399.125350  56642.907327  56626.703787  56958.133058
# 4          54823.472531  55088.146346  55114.497390  55465.004964
# 5          51680.112788  52165.725002  52157.866552  52336.590999
# 6          50810.531813  51320.086009  51411.322040  51408.387710
# 7          52647.477122  53314.431143  53186.989913  53305.035278
# 8          58153.995604  58788.751316  58830.511611  58985.960718
# 9          64829.891067  65473.069281  65583.730610  65850.016097
# 10         70626.560317  71176.975923  71402.433013  71575.337999
# 11         74607.253456  74981.588513  75574.103786  75627.372830
# 12         76959.967440  76955.507487  77716.565752  77397.794631
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#                  Datetime  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0     2017-01-01 00:00:00             34055.69620             16128.87538
# 1     2017-01-01 00:10:00             29814.68354             19375.07599
# 2     2017-01-01 00:20:00             29128.10127             19006.68693
# 3     2017-01-01 00:30:00             28228.86076             18361.09422
# 4     2017-01-01 00:40:00             27335.69620             17872.34043
# ...                   ...                     ...                     ...
# 52411 2017-12-30 23:10:00             31160.45627             26857.31820
# 52412 2017-12-30 23:20:00             30430.41825             26124.57809
# 52413 2017-12-30 23:30:00             29590.87452             25277.69254
# 52414 2017-12-30 23:40:00             28958.17490             24692.23688
# 52415 2017-12-30 23:50:00             28349.80989             24055.23167
#
#        PowerConsumption_Zone3  Total PowerConsumption  Hour  DayofWeek
# ...

# %%
df['Day_Name']=pd.Categorical(df['Datetime'].dt.day_name(),['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
df
# Out:
#                  Datetime  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0     2017-01-01 00:00:00             34055.69620             16128.87538
# 1     2017-01-01 00:10:00             29814.68354             19375.07599
# 2     2017-01-01 00:20:00             29128.10127             19006.68693
# 3     2017-01-01 00:30:00             28228.86076             18361.09422
# 4     2017-01-01 00:40:00             27335.69620             17872.34043
# ...                   ...                     ...                     ...
# 52411 2017-12-30 23:10:00             31160.45627             26857.31820
# 52412 2017-12-30 23:20:00             30430.41825             26124.57809
# 52413 2017-12-30 23:30:00             29590.87452             25277.69254
# 52414 2017-12-30 23:40:00             28958.17490             24692.23688
# 52415 2017-12-30 23:50:00             28349.80989             24055.23167
#
#        PowerConsumption_Zone3  Total PowerConsumption  Hour  DayofWeek  \
# ...

# %%
sns.heatmap(df.pivot_table(index='Hour',columns='Day_Name',values='Total PowerConsumption',aggfunc='mean'),cmap="coolwarm");
